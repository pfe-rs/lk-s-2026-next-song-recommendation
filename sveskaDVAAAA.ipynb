# %%
import os
import h5py
import pandas as pd

BASE_DIR = './MillionSongSubset'

# %%
sve_pesme = []
brojac_gresaka = 0
print("kreni")


for root, dirs, files in os.walk(BASE_DIR):
    for file in files:
        if file.endswith('.h5'):
            file_path = os.path.join(root, file)
       
            try:
                with h5py.File(file_path, 'r') as f:
                    meta_songs = f['metadata']['songs'][0]
                    raw_terms = f['metadata']['artist_terms'][:]
                    raw_artist_similarity = f['metadata']['similar_artists'][:]
                    raw_terms_weights = f['metadata']['artist_terms_weight'][:]
                   
                    song_id = meta_songs['song_id'].decode('utf-8', errors='replace')
                    artist_id =  meta_songs['artist_id'].decode('utf-8', errors='replace')
                    artist_terms = [term.decode('utf-8') for term in raw_terms]
                    artist_name = meta_songs['artist_name'].decode('utf-8', errors='replace')
                    artist_terms_weights = [weight for weight in raw_terms_weights]
                    analysis_songs = f['analysis']['songs'][0]
                    loudness = analysis_songs['loudness']
                    tempo = analysis_songs['tempo']
                    sim_art = [f.decode('utf-8') for f in raw_artist_similarity]
                    modes = int(analysis_songs['mode'])
                    mb_songs = f['musicbrainz']['songs'][0]
                    timesig = analysis_songs['time_signature']  
                    title = meta_songs['title'].decode('utf-8', errors='replace')
                    sve_pesme.append({

                       'song_id': song_id,
                        'artist_id': artist_id,
                        'title' : title,
                        'artist_name': artist_name,
                        'artist_terms': artist_terms,
                        'artist_terms_weight': artist_terms_weights,
                        'loudness': loudness,
                        'tempo': tempo,
                       'similar_artists': sim_art,
                        'mode': modes,
                        'time_signature': timesig
                    })
            except Exception as e:
                brojac_gresaka += 1
                if brojac_gresaka <= 3:
                    print(f"{file}: {e}")

print(f"grešaka: {brojac_gresaka}")

df = pd.DataFrame(sve_pesme)
print( {len(df)} )

if not df.empty:
    display(df.head())
# Out:
# Pokrećem skeniranje...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 28
#      26 sim_art = [f.decode('utf-8') for f in raw_artist_similarity]
#      27 modes = int(analysis_songs['mode'])
# ---> 28 mb_songs = f['musicbrainz']['songs'][0]
#      29 timesig = analysis_songs['time_signature']
#      30 title = meta_songs['title'].decode('utf-8', errors='replace')
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:57, in h5py._objects.with_phil.wrapper()
#
# File c:\Python\Lib\site-packages\h5py\_hl\dataset.py:804, in Dataset.__getitem__(self, args, new_dtype)
#     798     """Is this dataset suitable for simple reading"""
#     799     return (
#     800         self._extent_type == h5s.SIMPLE
#     801         and isinstance(self.id.get_type(), (h5t.TypeIntegerID, h5t.TypeFloatID))
#     802     )
# --> 804 @with_phil
#     805 def __getitem__(self, args, new_dtype=None):
#     806     """ Read a slice from the HDF5 dataset.
#     807
#     808     Takes slices and recarray-style field names (more than one is
#    (...)    814     * Boolean "mask" array indexing
#     815     """
#     816     args = args if isinstance(args, tuple) else (args,)
#
# KeyboardInterrupt:

# %%
def uzmi_prvih_pet(terms):
    if isinstance(terms, list):
        return terms[:5]
    return []

df['artist_terms'] = df['artist_terms'].apply(uzmi_prvih_pet)

for i, red in df.head(3).iterrows():
    print(f"Pesma {red['song_id']}: {red['artist_terms']}")

df.head()
# Out:
# Pesma SOMZWCG12A8C13C480: ['hip hop', 'underground rap', 'g funk', 'alternative rap', 'gothic rock']
# Pesma SOCIWDW12A8C13D406: ['blue-eyed soul', 'pop rock', 'blues-rock', 'beach music', 'soft rock']
# Pesma SOXVLOJ12AB0189215: ['salsa', 'cumbia', 'tejano', 'ranchera', 'latin pop']
#               song_id           artist_id             title       artist_name  \
# 0  SOMZWCG12A8C13C480  ARD7TVE1187B99BFB1  I Didn't Mean To            Casual
# 1  SOCIWDW12A8C13D406  ARMJAGH1187FB546F3         Soul Deep      The Box Tops
# 2  SOXVLOJ12AB0189215  ARKRRTF1187B9984DA   Amor De Cabaret  Sonora Santanera
# 3  SONHOTT12A8C13493C  AR7G5I41187FB4CE6C   Something Girls          Adam Ant
# 4  SOFSOCN12A8C143F5D  ARXR32B1187FB57099    Face the Ashes               Gob
#
#                                         artist_terms  \
# 0  [hip hop, underground rap, g funk, alternative...
# 1  [blue-eyed soul, pop rock, blues-rock, beach m...
# 2       [salsa, cumbia, tejano, ranchera, latin pop]
# 3  [pop rock, new wave, dance rock, rock, new rom...
# 4  [pop punk, ska punk, breakcore, alternative me...
#
#                                  artist_terms_weight  loudness    tempo  \
# 0  [1.0, 0.8979359555142553, 0.8842618474718359, ...   -11.197   92.198
# 1  [1.0, 0.8459884034332037, 0.8306895698215381, ...    -9.843  121.274
# 2  [1.0, 0.9582578450180738, 0.9582578450180738, ...    -9.689  100.070
# 3  [1.0, 0.9636972066614938, 0.9267729972686404, ...    -9.013  119.293
# 4  [1.0, 0.9609057433767874, 0.9592366232787087, ...    -4.501  129.738
#
#                                      similar_artists  mode  time_signature
# 0  [ARV4KO21187FB38008, ARWHM281187FB3D381, ARJGO...     0               4
# 1  [ARSZWK21187B9B26D7, ARLDW2Y1187B9B544F, ARG0T...     0               4
# 2  [ARFSJUG11C8A421AAD, AR8SD041187FB36015, ARR75...     1               1
# 3  [AR4R0741187FB39AF2, AR0D7K21187B9AD14E, ARRCB...     1               4
# 4  [ARUA62A1187B99D9B0, ARHJFFY1187B98BA76, ARHB1...     1               4

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

if not df.empty:
    
    def pripremi_terms(terms_list):
        if not isinstance(terms_list, list) or len(terms_list) == 0: 
            return ""
        return " ".join([term.replace(" ", "_") for term in terms_list])

=    df['terms_clean_text'] = df['artist_terms'].apply(pripremi_terms)

=    tfidf = TfidfVectorizer(max_features=1000)
    tfidf_matrica = tfidf.fit_transform(df['terms_clean_text'])

    
    print(f"TF-IDF matrica Pesme x Karakteristike: {tfidf_matrica.shape}")

    nauceni_tagovi = tfidf.get_feature_names_out()
    print(f"pr tagova{nauceni_tagovi[:10]}")
# Out:
# --- TF-IDF USPEŠNO ZAVRŠEN ---
# Oblik TF-IDF matrice (Pesme x Karakteristike): (10000, 927)
# Neki od naučenih tagova: ['00s' '2_tone' '60s' '60s_garage' '70s' '80s' '80s_pop' '90s' 'abstract'
#  'accordion']

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[['loudness', 'tempo']] = scaler.fit_transform(df[['loudness', 'tempo']])

display(df.head())
# Out:
#               song_id           artist_id             title       artist_name  \
# 0  SOMZWCG12A8C13C480  ARD7TVE1187B99BFB1  I Didn't Mean To            Casual
# 1  SOCIWDW12A8C13D406  ARMJAGH1187FB546F3         Soul Deep      The Box Tops
# 2  SOXVLOJ12AB0189215  ARKRRTF1187B9984DA   Amor De Cabaret  Sonora Santanera
# 3  SONHOTT12A8C13493C  AR7G5I41187FB4CE6C   Something Girls          Adam Ant
# 4  SOFSOCN12A8C143F5D  ARXR32B1187FB57099    Face the Ashes               Gob
#
#                                         artist_terms  \
# 0  [hip hop, underground rap, g funk, alternative...
# 1  [blue-eyed soul, pop rock, blues-rock, beach m...
# 2       [salsa, cumbia, tejano, ranchera, latin pop]
# 3  [pop rock, new wave, dance rock, rock, new rom...
# 4  [pop punk, ska punk, breakcore, alternative me...
#
#                                  artist_terms_weight  loudness     tempo  \
# 0  [1.0, 0.8979359555142553, 0.8842618474718359, ...  0.774694  0.350792
# 1  [1.0, 0.8459884034332037, 0.8306895698215381, ...  0.800628  0.461420
# 2  [1.0, 0.9582578450180738, 0.9582578450180738, ...  0.803578  0.380743
# 3  [1.0, 0.9636972066614938, 0.9267729972686404, ...  0.816526  0.453882
# 4  [1.0, 0.9609057433767874, 0.9592366232787087, ...  0.902948  0.493623
#
#                                      similar_artists  mode  time_signature  \
# 0  [ARV4KO21187FB38008, ARWHM281187FB3D381, ARJGO...     0               4
# 1  [ARSZWK21187B9B26D7, ARLDW2Y1187B9B544F, ARG0T...     0               4
# 2  [ARFSJUG11C8A421AAD, AR8SD041187FB36015, ARR75...     1               1
# 3  [AR4R0741187FB39AF2, AR0D7K21187B9AD14E, ARRCB...     1               4
# 4  [ARUA62A1187B99D9B0, ARHJFFY1187B98BA76, ARHB1...     1               4
#
#                                     terms_clean_text
# 0  hip_hop underground_rap g_funk alternative_rap...
# 1  blue-eyed_soul pop_rock blues-rock beach_music...
# 2             salsa cumbia tejano ranchera latin_pop
# 3     pop_rock new_wave dance_rock rock new_romantic
# 4  pop_punk ska_punk breakcore alternative_metal ...

# %%
import glob
import json
import pandas as pd

prvi_dataset_songs = set(
    df["artist_name"].astype(str).str.strip().str.lower()
    + " - "
    + df["title"].astype(str).str.strip().str.lower()
)

print(f"usepsno ucitane pesme {len(prvi_dataset_songs)}")


json_folder_path = r"C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\*.json"  # Primer: "C:/putanja/do/foldera/*.json"

json_songs = set()
json_files = glob.glob(json_folder_path)


if len(json_files) == 0:
    print("Python ne vidi ni jedan JSON fajl. Proveri da li je putanja 100% tačna!")
else:
    for file_path in json_files:
        with open(file_path, "r", encoding="utf-8") as f:
            data = json.load(f)
            
            if "playlists" not in data:
                print(f"Fajl {file_path} nema ključ 'playlists'. Ključevi su: {list(data.keys())}")
                continue
                
            playlists_list = data.get("playlists", [])
            print(f"fajl {file_path} br plejlisti: {len(playlists_list)}")
            
            for playlist in playlists_list:
                tracks_list = playlist.get("tracks", [])
                for track in tracks_list:
                    artist = track.get("artist_name")
                    track_name = track.get("track_name")
                    
                    if artist is None or track_name is None:
                        print(f"dostupni ključevi: {list(track.keys())}")
                        break
                        
                    song_key = str(artist).strip().lower() + " - " + str(track_name).strip().lower()
                    json_songs.add(song_key)

print(f"\nUkupan broj unikatnih pesama uspešno pokupljenih iz JSON-a: {len(json_songs)}")
# Out:
# Uspešno učitano! Broj unikatnih pesama u tvom prvom datasetu: 9939
# Putanja koju pretražujem: C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\*.json
# Broj pronađenih JSON fajlova na toj putanji: 1000
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.0-999.json... Nađeno plejlisti: 89
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.1000-1999.json... Nađeno plejlisti: 80
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.10000-10999.json... Nađeno plejlisti: 72
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.100000-100999.json... Nađeno plejlisti: 96
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.101000-101999.json... Nađeno plejlisti: 82
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.102000-102999.json... Nađeno plejlisti: 97
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.103000-103999.json... Nađeno plejlisti: 84
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.104000-104999.json... Nađeno plejlisti: 93
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.105000-105999.json... Nađeno plejlisti: 86
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.106000-106999.json... Nađeno plejlisti: 85
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.107000-107999.json... Nađeno plejlisti: 81
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.108000-108999.json... Nađeno plejlisti: 86
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.109000-109999.json... Nađeno plejlisti: 73
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.11000-11999.json... Nađeno plejlisti: 84
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.110000-110999.json... Nađeno plejlisti: 101
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.111000-111999.json... Nađeno plejlisti: 85
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.112000-112999.json... Nađeno plejlisti: 98
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.113000-113999.json... Nađeno plejlisti: 90
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.114000-114999.json... Nađeno plejlisti: 75
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.115000-115999.json... Nađeno plejlisti: 81
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.116000-116999.json... Nađeno plejlisti: 75
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.117000-117999.json... Nađeno plejlisti: 74
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.118000-118999.json... Nađeno plejlisti: 93
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.119000-119999.json... Nađeno plejlisti: 85
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.12000-12999.json... Nađeno plejlisti: 90
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.120000-120999.json... Nađeno plejlisti: 90
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.121000-121999.json... Nađeno plejlisti: 79
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.122000-122999.json... Nađeno plejlisti: 80
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.123000-123999.json... Nađeno plejlisti: 86
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.124000-124999.json... Nađeno plejlisti: 101
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.125000-125999.json... Nađeno plejlisti: 106
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.126000-126999.json... Nađeno plejlisti: 80
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.127000-127999.json... Nađeno plejlisti: 87
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.128000-128999.json... Nađeno plejlisti: 95
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.129000-129999.json... Nađeno plejlisti: 89
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.13000-13999.json... Nađeno plejlisti: 86
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.130000-130999.json... Nađeno plejlisti: 75
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.131000-131999.json... Nađeno plejlisti: 88
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.132000-132999.json... Nađeno plejlisti: 85
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.133000-133999.json... Nađeno plejlisti: 71
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.134000-134999.json... Nađeno plejlisti: 81
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.135000-135999.json... Nađeno plejlisti: 82
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.136000-136999.json... Nađeno plejlisti: 82
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.137000-137999.json... Nađeno plejlisti: 84
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.138000-138999.json... Nađeno plejlisti: 83
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.139000-139999.json... Nađeno plejlisti: 87
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.14000-14999.json... Nađeno plejlisti: 84
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.140000-140999.json... Nađeno plejlisti: 74
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.988000-988999.json... Nađeno plejlisti: 90
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.989000-989999.json... Nađeno plejlisti: 86
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.99000-99999.json... Nađeno plejlisti: 84
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.990000-990999.json... Nađeno plejlisti: 85
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.991000-991999.json... Nađeno plejlisti: 97
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.992000-992999.json... Nađeno plejlisti: 91
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.993000-993999.json... Nađeno plejlisti: 83
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.994000-994999.json... Nađeno plejlisti: 93
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.995000-995999.json... Nađeno plejlisti: 91
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.996000-996999.json... Nađeno plejlisti: 97
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.997000-997999.json... Nađeno plejlisti: 93
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.998000-998999.json... Nađeno plejlisti: 89
# Učitavam fajl C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\mpd.slice.999000-999999.json... Nađeno plejlisti: 75
#
# Ukupan broj unikatnih pesama uspešno pokupljenih iz JSON-a: 1767

# %%
zajednicki_kljucevi = prvi_dataset_songs.keys() & json_songs.keys() if isinstance(prvi_dataset_songs, dict) else set(prvi_dataset_songs).intersection(set(json_songs))


lista_zajednickih = []
for kljuc in zajednicki_kljucevi:
    if isinstance(prvi_dataset_songs, dict) and isinstance(json_songs, dict):
        lista_zajednickih.append({
            'artist_name': prvi_dataset_songs[kljuc]['artist'],
            'song_name': prvi_dataset_songs[kljuc]['title']
        })
    else:
        delovi = kljuc.split(" - ")
        if len(delovi) >= 2:
            lista_zajednickih.append({
                'artist_name': delovi[0].title(),
                'song_name': " - ".join(delovi[1:]).title()
            })

df_zajednicke = pd.DataFrame(lista_zajednickih)
df_zajednicke.head(400000)
df_zajednicke.to_csv(
    r"C:\Users\Lena\Downloads\millionsongsubset\zajednicke_pesme.csv",
    index=False,
    encoding="utf-8-sig",
)

# %%
putanja_csv = r"C:\Users\Lena\Downloads\millionsongsubset\zajednicke_pesme.csv"
df_zajednicke = pd.read_csv(putanja_csv)

dozvoljene_pesme = set(
    df_zajednicke["artist_name"].astype(str).str.strip().str.lower()
    + " - "
    + df_zajednicke["song_name"].astype(str).str.strip().str.lower()
)

print(f"uvitano {len(dozvoljene_pesme)} zaj pesama")

json_folder_path = r"C:\Users\Lena\Downloads\millionsongsubset\spotify_million_playlist_dataset\data\*.json"
json_files = glob.glob(json_folder_path)

print(f"nađeno {len(json_files)} JSON fajlova ")

ukupno_pre = 0
ukupno_posle = 0

for file_path in json_files:
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    fajl_izmenjen = False

    
    for playlist in data.get("playlists", []):
        ociscene_trake = []
        tracks_list = playlist.get("tracks", [])
        ukupno_pre += len(tracks_list)

        for track in tracks_list:
            art_json = str(track.get("artist_name", "")).strip().lower()
            track_json = str(track.get("track_name", "")).strip().lower()
            kljuc = f"{art_json} - {track_json}"

            
            if kljuc in dozvoljene_pesme:
                ociscene_trake.append(track)
            else:
                fajl_izmenjen = True

        playlist["tracks"] = ociscene_trake
        ukupno_posle += len(ociscene_trake)

    if fajl_izmenjen:
        with open(file_path, "w", encoding="utf-8") as f:
            json.dump(data, f, indent=4, ensure_ascii=False)

print("=" * 60)
print(f"br pesama pre brisanja: {ukupno_pre}")
print(f"br pesama posle brisanja: {ukupno_posle}")
print(f"izbrisano: {ukupno_pre - ukupno_posle}")
print("=" * 60)
# Out:
# Učitano 1767 dozvoljenih pesama iz CSV-a.
# Pronađeno 1000 JSON fajlova za filtriranje...
# ============================================================
# ČIŠĆENJE JSON FAJLOVA JE USPEŠNO ZAVRŠENO!
# Ukupno pesama PRE brisanja: 256136
# Ukupno pesama POSLE brisanja: 256136
# Izbrisano pesama: 0
# ============================================================

# %%
broj_unikatnih_pesama = len(df_zajednicke.drop_duplicates(subset=['artist_name', 'song_name']))
print(f"Suma: {broj_unikatnih_pesama}")
# Out:
# Ukupan broj unikatnih pesama u celom datasetu: 1767

# %% [markdown]
# #### SPAJAMO TRAIN_TRIPLETS.TXT I JSON FAJLOVE

# %%
df_interactions = pd.read_csv(r'C:\Users\Lena\Downloads\millionsongsubset\train_triplets.txt\train_triplets.txt', sep='\t', names=['user_id', 'song_id', 'play_count'], nrows=1000000)

pesme_u_datasetu_1 = set(df['song_id'])


print(df_interactions['song_id'].nunique())

df_interactions = df_interactions[df_interactions['song_id'].isin(pesme_u_datasetu_1)].copy()

print(df_interactions['song_id'].nunique())
df_filtriran = df_interactions.reset_index(drop=True)

if not df_filtriran.empty:
    display(df_filtriran.head())


# #dodajemo podatke i z json fajlova u train_triplets
# for row in df_interactions.itertuples():
#     user_id = row.user_id
#     song_id = row.song_id
#     play_count = 1

# df_interactions.head(1000000000)
# Out:
# 148039
# 1580
#                                     user_id             song_id  play_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOWEZSI12A81C21CE6           1
# 1  4bd88bfb25263a75bbdd467e74018f4ae570e5df  SODCXXY12AB0187452           2
# 2  4bd88bfb25263a75bbdd467e74018f4ae570e5df  SOWPAXV12A67ADA046          18
# 3  b64cdd1a0bd907e5e00b39e345194768e330d652  SOLXDDC12A6701FBFD           1
# 4  b64cdd1a0bd907e5e00b39e345194768e330d652  SONJBQX12A6D4F8382           4

# %%
import glob
import json
import pandas as pd

rows = []


for file_path in json_files:
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)
        
        playlists_list = data.get("playlists", [])
        for playlist in playlists_list:
            user_id = playlist.get("name")
            
            tracks_list = playlist.get("tracks", [])
            for track in tracks_list:
                artist = track.get("artist_name")
                track_name = track.get("track_name")
                
                if artist and track_name:
                    song_id = f"{artist.strip()} - {track_name.strip()}"
                    
                    rows.append({
                        "user_id": user_id,
                        "song_id": song_id,
                        "play_count": 1
                    })

df_json = pd.DataFrame(rows)
df_filtriran = pd.concat([df_filtriran, df_json], ignore_index=True)
print(f"redova {len(df_filtriran)}")

print(df_filtriran.head(1000000))
# Out:
# Pronađeno 1000 JSON fajlova. Pokrećem izvlačenje podataka...
#
# Gotovo! Napravljen df_filtriran.
# Ukupan broj redova u novom datasetu: 271831
#
# Prva 5 reda tvog novog dataseta:
#                                          user_id  \
# 0       b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1       4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 2       4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 3       b64cdd1a0bd907e5e00b39e345194768e330d652
# 4       b64cdd1a0bd907e5e00b39e345194768e330d652
# ...                                          ...
# 271826                                       80s
# 271827                                      Lake
# 271828                                      Lake
# 271829                                      Lake
# 271830                                      Lake
#
#                                                   song_id  play_count
# 0                                      SOWEZSI12A81C21CE6           1
# 1                                      SODCXXY12AB0187452           2
# 2                                      SOWPAXV12A67ADA046          18
# 3                                      SOLXDDC12A6701FBFD           1
# 4                                      SONJBQX12A6D4F8382           4
# ...                                                   ...         ...
# 271826              Rick Astley - Never Gonna Give You Up           1
# 271827  Tom Petty and the Heartbreakers - Mary Jane's ...           1
# 271828                Daryl Hall & John Oates - Rich Girl           1
# 271829                               Maroon 5 - This Love           1
# 271830  Tom Petty and the Heartbreakers - Mary Jane's ...           1
#
# [271831 rows x 3 columns]

# %%
csv_output_path = "filtriran_dataset.csv"
df_filtriran.to_csv(csv_output_path, index=False, encoding="utf-8")
# Out:
# Uspešno napravljen CSV fajl!
# Putanja fajla: /home/jovyan/filtriran_dataset.csv

# %% [markdown]
# #### RADIMO COUSIN SIM ZA SPOJENE DATASETOVE

# %%
import pandas as pd

df_karakteristike = df[
    ["song_id", "artist_id", "artist_terms", "loudness", "tempo", "time_signature", "similar_artists"]
].copy()

df_karakteristike = df_karakteristike.drop_duplicates(
    subset=["song_id"]
)

df_finalni = pd.merge(
    df_filtriran,
    df_karakteristike,
    left_on=["song_id"],
    right_on=["song_id"],
    how="left",
)

if "title" in df_finalni.columns:
    df_finalni = df_finalni.drop(columns=["title"])


display(df_finalni.head())
# Out:
# ✅ Uspešno spojeno!
# Broj redova ostao isti: 271831
# Nove dostupne kolone: ['user_id', 'song_id', 'play_count', 'artist_id', 'artist_terms', 'loudness', 'tempo', 'time_signature', 'similar_artists']
#                                     user_id             song_id  play_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOWEZSI12A81C21CE6           1
# 1  4bd88bfb25263a75bbdd467e74018f4ae570e5df  SODCXXY12AB0187452           2
# 2  4bd88bfb25263a75bbdd467e74018f4ae570e5df  SOWPAXV12A67ADA046          18
# 3  b64cdd1a0bd907e5e00b39e345194768e330d652  SOLXDDC12A6701FBFD           1
# 4  b64cdd1a0bd907e5e00b39e345194768e330d652  SONJBQX12A6D4F8382           4
#
#             artist_id                                       artist_terms  \
# 0  AR2UQQ51187B9AC816    [flamenco, soundtrack, folk, spanish, acoustic]
# 1  ARXLMH011C8A415658      [pop rap, crunk, rapcore, screamo, breakcore]
# 2  ARUQ6301187FB54EBA  [pop rap, hip hop, hip house, new jack swing, ...
# 3  ARTH9041187FB43E1F     [hip hop, rap, hardcore rap, club, soundtrack]
# 4  ARF8HTQ1187B9AE693     [techno, electronica, electronic, pop, french]
#
#    loudness     tempo  time_signature  \
# 0  0.828210  0.627810             1.0
# 1  0.767205  0.455096             4.0
# 2  0.880595  0.485477             4.0
# 3  0.912755  0.685498             4.0
# 4  0.893026  0.423094             4.0
#
#                                      similar_artists
# 0  [AR9Z7JB1187B99DB3D, ARC1SF21187FB51D0F, AR0F5...
# 1  [ARHAUVU122BCFCBA38, AR258TI11C8A416B5B, ARX94...
# 2  [ARNHMFD1187FB3B3F6, ARELPXQ1187FB384FD, ARX9Y...
# 3  [AR23C041187FB4D534, ARZER7I1187FB385AF, ARDD0...
# 4  [AR3NPVS1187FB5108F, ARMKBL21187FB38230, ARYJ8...

# %%
from scipy.sparse import hstack, csr_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler

if not df_finalni.empty:

    def pripremi_terms(terms_list):
        if not isinstance(terms_list, list) or len(terms_list) == 0:
            return ""
        return " ".join([term.replace(" ", "_") for term in terms_list])

    df_finalni["terms_clean_text"] = df_finalni["artist_terms"].apply(
        pripremi_terms
    )

    tfidf = TfidfVectorizer(max_features=1000)
    tfidf_matrica = tfidf.fit_transform(df_finalni["terms_clean_text"])

    ts_min = df_finalni["time_signature"].fillna(0).min()
    ts_max = df_finalni["time_signature"].fillna(0).max()

    if ts_max != ts_min:
        time_sig_norm = (df_finalni["time_signature"].fillna(0) - ts_min) / (
            ts_max - ts_min
        )
    else:
        time_sig_norm = df_finalni["time_signature"].fillna(0)

    l_norm = df_finalni["loudness"].values
    t_norm = df_finalni["tempo"].values
    ts_norm = time_sig_norm.values

    numericke_karakteristike = np.vstack([l_norm, t_norm, ts_norm]).T
    numericke_sparse = csr_matrix(numericke_karakteristike)

    tfidf_matrix = hstack([tfidf_matrica, numericke_sparse]).tocsr()

    print(
        f"Pesme x Sve karakteristike {tfidf_matrix.shape}"
    )
# Out:
# Konačan oblik matrice (Pesme x Sve karakteristike): (527967, 579)

# %%
def generisi_content_based_preporuke_safe(
    target_user_id,
    interakcije_df,
    konacni_vektori_pesama,
    song_id_u_indeks,
    df_pesme,
    top_n=10,
):
    korisnik_istorija = interakcije_df[
        interakcije_df["user_id"] == target_user_id
    ]

    if korisnik_istorija.empty:
        print(f"user {target_user_id} nije muzikalan.")
        return []

    profil_korisnika = None
    ukupno_pustanja = 0

    for _, red in korisnik_istorija.iterrows():
        s_id = red["song_id"]
        broj_slusanja = red["play_count"]

        if s_id in song_id_u_indeks:
            indeks_pesme = song_id_u_indeks[s_id]
            vektor_pesme = konacni_vektori_pesama.getrow(indeks_pesme)

            if profil_korisnika is None:
                profil_korisnika = vektor_pesme * broj_slusanja
            else:
                profil_korisnika += vektor_pesme * broj_slusanja

            ukupno_pustanja += broj_slusanja

    if profil_korisnika is None:
        print(f"user {target_user_id} nije muzikalan.")
        return []

    profil_korisnika = profil_korisnika / ukupno_pustanja


    konacni_vektori_pesama.data = np.nan_to_num(konacni_vektori_pesama.data)
    profil_korisnika.data = np.nan_to_num(profil_korisnika.data)

    skorovi_slicnosti = cosine_similarity(
        profil_korisnika, konacni_vektori_pesama
    )[0]
    rangirani_indeksi = np.argsort(skorovi_slicnosti)[::-1]

    
    slusane_pesme_ids = set(korisnik_istorija["song_id"])
    vec_preporuceno_ids = set()

    preporuke = []

    kolona_naslov = (
        "song_name"
        if "song_name" in df_pesme.columns
        else (
            "title"
            if "title" in df_pesme.columns
            else (
                "song_title" if "song_title" in df_pesme.columns else None
            )
        )
    )

    for indeks in rangirani_indeksi:
        pesma_info = df_pesme.iloc[indeks]
        s_id = pesma_info["song_id"]

        if s_id not in slusane_pesme_ids and s_id not in vec_preporuceno_ids:

            prikazni_naslov = (
                pesma_info[kolona_naslov]
                if kolona_naslov
                else s_id
            )

            preporuke.append(
                {
                    "title": prikazni_naslov,
                    "song_id": s_id,
                    "score": skorovi_slicnosti[indeks],
                }
            )

            vec_preporuceno_ids.add(s_id)

        if len(preporuke) == top_n:
            break

    return preporuke

# %%
tekstualni_nizovi = df_finalni["artist_terms"].apply(
    lambda x: (
        " ".join([tag.replace(" ", "_") for tag in x])
        if isinstance(x, list)
        else ""
    )
)

song_id_u_indeks = {
    song_id: idx for idx, song_id in enumerate(df_finalni["song_id"])
}


pesme_u_matrici = set(df_finalni["song_id"].unique())
df_interactions_sigurno = df_interactions_filtrirano[
    df_interactions_filtrirano["song_id"].isin(pesme_u_matrici)
].copy()

target_user_id = df_interactions_sigurno["user_id"].value_counts().index[0]
print(f"Računam nove preporuke za korisnika: {target_user_id}...")


preporuke_napredne = generisi_content_based_preporuke_safe(
    target_user_id=target_user_id,
    interakcije_df=df_interactions_sigurno,
    konacni_vektori_pesama=tfidf_matrix,  
    song_id_u_indeks=song_id_u_indeks,
    df_pesme=df_finalni,
    top_n=10,
)


if preporuke_napredne:
    print(
        f"\ntop 10"
    )
    print("-" * 75)
    for rank, p in enumerate(preporuke_napredne, 1):
        print(
            f"{rank}. {p['title']} [{p['song_id']}] (Sličnost: {p['score']:.4f})"
        )
else:
    print("\n uh ne treba ovo ovako")
# Out:
# Rečnik 'song_id_u_indeks' je spreman.
# Računam nove preporuke za korisnika: 1aa4fd215aadb160965110ed8a829745cde319eb...
#
# NOVI TOP 10 REZULTATI:
# ---------------------------------------------------------------------------
# 1. SONBEKD12AB01894DC [SONBEKD12AB01894DC] (Sličnost: 0.8839)
# 2. SOOCZWD12AB0185147 [SOOCZWD12AB0185147] (Sličnost: 0.8380)
# 3. SOYXFLF12A6D4FBF4E [SOYXFLF12A6D4FBF4E] (Sličnost: 0.8343)
# 4. SOZRIFJ12A67ADA4BE [SOZRIFJ12A67ADA4BE] (Sličnost: 0.8316)
# 5. SOYDZUT12A8C13677D [SOYDZUT12A8C13677D] (Sličnost: 0.8315)
# 6. SODHVES12A6701CE6B [SODHVES12A6701CE6B] (Sličnost: 0.8288)
# 7. SOJGCRU12A8C1323B7 [SOJGCRU12A8C1323B7] (Sličnost: 0.8230)
# 8. SOQLWQU12A8C13C87E [SOQLWQU12A8C13C87E] (Sličnost: 0.8220)
# 9. SOLMCFH12A58A7FACE [SOLMCFH12A58A7FACE] (Sličnost: 0.8205)
# 10. SOCOZKO12B0B8066E3 [SOCOZKO12B0B8066E3] (Sličnost: 0.8189)

# %%
def kreiraj_train_test_interakcije(df_interakcije, test_pesama_po_korisniku=2):
    train_list = []
    test_list = []
    
    for user_id, group in df_interakcije.groupby('user_id'):
        if len(group) <= test_pesama_po_korisniku:
            train_list.append(group)
        else:
            test_uzorak = group.sample(n=test_pesama_po_korisniku, random_state=42)
            train_uzorak = group.drop(test_uzorak.index)
            
            train_list.append(train_uzorak)
            test_list.append(test_uzorak)
            
    df_train = pd.concat(train_list).reset_index(drop=True)
    df_test = pd.concat(test_list).reset_index(drop=True)
    
    return df_train, df_test


df_train, df_test = kreiraj_train_test_interakcije(df_interactions_sigurno, test_pesama_po_korisniku=2)

print(f"tnterakcije treninga {len(df_train)}")
print(f"interakcije testa{len(df_test)}")
# Out:
# Ukupno interakcija u TRAIN setu: 12411
# Ukupno interakcija u TEST setu: 3284

# %%
import scipy.sparse as sp
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split

def evaluiraj_maksimalni_cb(
    df_train,
    df_test,
    kombinovana_matrica,
    song_id_u_indeks,
    df_pesme,
    top_n=10,
):
    ukupno_hitova = 0
    ukupno_preciznost = 0.0
    procenjeni_korisnici = 0

    test_users = df_test["user_id"].unique()

    kolona_slusanja = (
        "play_count" if "play_count" in df_train.columns else "listen_count"
    )
    kombinovana_matrica = kombinovana_matrica.tocsr()

    kombinovana_matrica.data = np.nan_to_num(kombinovana_matrica.data)

    for target_user_id in test_users:
        user_train = df_train[df_train["user_id"] == target_user_id]
        if user_train.empty:
            continue

        user_test_pesme = set(
            df_test[df_test["user_id"] == target_user_id]["song_id"]
        )

        profil_korisnika = sp.csr_matrix(
            (1, kombinovana_matrica.shape[1]), dtype=np.float64
        )
        ukupno_pustanja = 0

        for _, red in user_train.iterrows():
            s_id = red["song_id"]
            broj_slusanja = red[kolona_slusanja]

            if s_id in song_id_u_indeks:
                idx_p = song_id_u_indeks[s_id]
                profil_korisnika += (
                    kombinovana_matrica.getrow(idx_p) * broj_slusanja
                )
                ukupno_pustanja += broj_slusanja

        if ukupno_pustanja == 0:
            continue

        profil_korisnika = profil_korisnika / ukupno_pustanja

        skorovi = cosine_similarity(
            profil_korisnika, kombinovana_matrica
        ).flatten()
        top_indeksi = np.argsort(skorovi)[::-1]

        skup_slusanih_id = set(user_train["song_id"])
        preporuke_id = []
        vec_dodato = set()

        for idx in top_indeksi:
            pesma_info = df_pesme.iloc[idx]
            s_id = pesma_info["song_id"]

            if s_id not in skup_slusanih_id and s_id not in vec_dodato:
                preporuke_id.append(s_id)
                vec_dodato.add(s_id)

            if len(preporuke_id) == top_n:
                break

        pogoci = [pesma for pesma in preporuke_id if pesma in user_test_pesme]
        broj_pogodaka = len(pogoci)

        if broj_pogodaka > 0:
            ukupno_hitova += 1
        ukupno_preciznost += broj_pogodaka / top_n
        procenjeni_korisnici += 1

    prosecan_hr = (
        ukupno_hitova / procenjeni_korisnici if procenjeni_korisnici > 0 else 0
    )
    prosecna_preciznost = (
        ukupno_preciznost / procenjeni_korisnici
        if procenjeni_korisnici > 0
        else 0
    )
    
    
    print(f"Evaluirano korisnika: {procenjeni_korisnici}")
    print(f"Hit Rate@{top_n}:     {prosecan_hr:.4f}")
    print(f"Precision@{top_n}:    {prosecna_preciznost:.4f}")

    return prosecan_hr, prosecna_preciznost


izvor_interakcija = df_finalni


train_list = []
#val_list = []
test_list = []

for user_id, group in izvor_interakcija.groupby("user_id"):
    n_samples = len(group)

    if n_samples >= 6:
        # u_train, u_ostatak = train_test_split(
        #     group, test_size=0.30, shuffle=True, random_state=42
        # )
        # u_val, u_test = train_test_split(
        #     u_ostatak, test_size=0.50, shuffle=True, random_state=42
        # )
        u_train, u_test = train_test_split(
           group, test_size=0.30, shuffle=True, random_state=42
        )
        train_list.append(u_train)
        # val_list.append(u_val)
        test_list.append(u_test)

    # 2. Korisnici sa 3, 4 ili 5 pesama - ručno raspoređujemo da izbegnemo prazne setove
    elif 3 <= n_samples <= 5:
        # Promešamo grupu pre ručne podele
        group_shuffled = group.sample(frac=1, random_state=42)

        # Ovdje uvek dajemo 1 pesmu u val, 1 u test, a ostatak (1, 2 ili 3 pesme) ide u train
        u_val = group_shuffled.iloc[[0]]
        u_test = group_shuffled.iloc[[1]]
        u_train = group_shuffled.iloc[2:]

        train_list.append(u_train)
        # val_list.append(u_val)
        test_list.append(u_test)

    # 3. Korisnici sa tačno 2 pesme - 1 u train, 1 u test (val ostaje prazan za njih)
    elif n_samples == 2:
        u_train, u_test = train_test_split(
            group, test_size=0.50, shuffle=True, random_state=42
        )
        train_list.append(u_train)
        test_list.append(u_test)

    
    else:
        train_list.append(group)


df_train = pd.concat(train_list, ignore_index=True)
# df_val = pd.concat(val_list, ignore_index=True) if val_list else pd.DataFrame()
df_test = pd.concat(test_list, ignore_index=True)

print(f"Veličina train seta:       {df_train.shape[0]} interakcija")
# print(f"Veličina validation seta:  {df_val.shape[0]} interakcija")
print(f"Veličina test seta:        {df_test.shape[0]} interakcija\n")


hr_full, prec_full = evaluiraj_maksimalni_cb(
    df_train=df_train,
    df_test=df_test,  
    kombinovana_matrica=tfidf_matrix,
    song_id_u_indeks=song_id_u_indeks,
    df_pesme=df_finalni,
    top_n=15,
)
# Out:
# Pravim stabilan Train(70%) / Val(15%) / Test(15%) split...
# Veličina train seta:       177091 interakcija
# Veličina validation seta:  40420 interakcija
# Veličina test seta:        54320 interakcija
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 178
#     169 print(f"Veličina test seta:        {df_test.shape[0]} interakcija\n")
#     172 # =====================================================================
#     173 # 3. POKRETANJE EVALUACIJE
#     174 # =====================================================================
#     175 hr_full, prec_full = evaluiraj_maksimalni_cb(
#     176     df_train=df_train,
#     177     df_test=df_test,  # Evaluaciju radimo na test skupu
# --> 178     kombinovana_matrica=tfidf_matrix,
#     179     song_id_u_indeks=song_id_u_indeks,
#     180     df_pesme=df_finalni,
#     181     top_n=15,
#     182 )
#
# NameError: name 'tfidf_matrix' is not defined
