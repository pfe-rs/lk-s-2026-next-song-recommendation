# %% [markdown]
# ## biblioteke

# %%
import os
import h5py
import pandas as pd

BASE_DIR = './MillionSongSubset'

# %%
from implicit.als import AlternatingLeastSquares
import pickle

# %% [markdown]
# ## ucitavanje seta

# %%
df_fin = pd.read_csv('mergeovan.csv')

display(df_fin.head())
# Out:
#                                     user_id             song_id  play_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOWEZSI12A81C21CE6           1
# 1  4bd88bfb25263a75bbdd467e74018f4ae570e5df  SODCXXY12AB0187452           2
# 2  4bd88bfb25263a75bbdd467e74018f4ae570e5df  SOWPAXV12A67ADA046          18
# 3  b64cdd1a0bd907e5e00b39e345194768e330d652  SOLXDDC12A6701FBFD           1
# 4  b64cdd1a0bd907e5e00b39e345194768e330d652  SONJBQX12A6D4F8382           4
#
#   artist_name           artist_id  \
# 0         NaN  AR2UQQ51187B9AC816
# 1         NaN  ARXLMH011C8A415658
# 2         NaN  ARUQ6301187FB54EBA
# 3         NaN  ARTH9041187FB43E1F
# 4         NaN  ARF8HTQ1187B9AE693
#
#                                         artist_terms  loudness     tempo  \
# 0  ['flamenco', 'soundtrack', 'folk', 'spanish', ...  0.828210  0.627810
# 1  ['pop rap', 'crunk', 'rapcore', 'screamo', 'br...  0.767205  0.455096
# 2  ['pop rap', 'hip hop', 'hip house', 'new jack ...  0.880595  0.485477
# 3  ['hip hop', 'rap', 'hardcore rap', 'club', 'so...  0.912755  0.685498
# 4  ['techno', 'electronica', 'electronic', 'pop',...  0.893026  0.423094
#
#    time_signature                                    similar_artists
# 0               1  ['AR9Z7JB1187B99DB3D', 'ARC1SF21187FB51D0F', '...
# 1               4  ['ARHAUVU122BCFCBA38', 'AR258TI11C8A416B5B', '...
# 2               4  ['ARNHMFD1187FB3B3F6', 'ARELPXQ1187FB384FD', '...
# 3               4  ['AR23C041187FB4D534', 'ARZER7I1187FB385AF', '...
# 4               4  ['AR3NPVS1187FB5108F', 'ARMKBL21187FB38230', '...

# %%
print(df_fin['song_id'].nunique())
# Out:
# 2700

# %%
df_finalni = df_fin.drop(columns=["artist_name"]).copy()

df_finalni.head()
# Out:
#                                     user_id             song_id  play_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOWEZSI12A81C21CE6           1
# 1  4bd88bfb25263a75bbdd467e74018f4ae570e5df  SODCXXY12AB0187452           2
# 2  4bd88bfb25263a75bbdd467e74018f4ae570e5df  SOWPAXV12A67ADA046          18
# 3  b64cdd1a0bd907e5e00b39e345194768e330d652  SOLXDDC12A6701FBFD           1
# 4  b64cdd1a0bd907e5e00b39e345194768e330d652  SONJBQX12A6D4F8382           4
#
#             artist_id                                       artist_terms  \
# 0  AR2UQQ51187B9AC816  ['flamenco', 'soundtrack', 'folk', 'spanish', ...
# 1  ARXLMH011C8A415658  ['pop rap', 'crunk', 'rapcore', 'screamo', 'br...
# 2  ARUQ6301187FB54EBA  ['pop rap', 'hip hop', 'hip house', 'new jack ...
# 3  ARTH9041187FB43E1F  ['hip hop', 'rap', 'hardcore rap', 'club', 'so...
# 4  ARF8HTQ1187B9AE693  ['techno', 'electronica', 'electronic', 'pop',...
#
#    loudness     tempo  time_signature  \
# 0  0.828210  0.627810               1
# 1  0.767205  0.455096               4
# 2  0.880595  0.485477               4
# 3  0.912755  0.685498               4
# 4  0.893026  0.423094               4
#
#                                      similar_artists
# 0  ['AR9Z7JB1187B99DB3D', 'ARC1SF21187FB51D0F', '...
# 1  ['ARHAUVU122BCFCBA38', 'AR258TI11C8A416B5B', '...
# 2  ['ARNHMFD1187FB3B3F6', 'ARELPXQ1187FB384FD', '...
# 3  ['AR23C041187FB4D534', 'ARZER7I1187FB385AF', '...
# 4  ['AR3NPVS1187FB5108F', 'ARMKBL21187FB38230', '...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df_finalni[['time_signature']] = scaler.fit_transform(df_finalni[['time_signature']])

display(df_finalni.head())
# Out:
#                                     user_id             song_id  play_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOWEZSI12A81C21CE6           1
# 1  4bd88bfb25263a75bbdd467e74018f4ae570e5df  SODCXXY12AB0187452           2
# 2  4bd88bfb25263a75bbdd467e74018f4ae570e5df  SOWPAXV12A67ADA046          18
# 3  b64cdd1a0bd907e5e00b39e345194768e330d652  SOLXDDC12A6701FBFD           1
# 4  b64cdd1a0bd907e5e00b39e345194768e330d652  SONJBQX12A6D4F8382           4
#
#             artist_id                                       artist_terms  \
# 0  AR2UQQ51187B9AC816  ['flamenco', 'soundtrack', 'folk', 'spanish', ...
# 1  ARXLMH011C8A415658  ['pop rap', 'crunk', 'rapcore', 'screamo', 'br...
# 2  ARUQ6301187FB54EBA  ['pop rap', 'hip hop', 'hip house', 'new jack ...
# 3  ARTH9041187FB43E1F  ['hip hop', 'rap', 'hardcore rap', 'club', 'so...
# 4  ARF8HTQ1187B9AE693  ['techno', 'electronica', 'electronic', 'pop',...
#
#    loudness     tempo  time_signature  \
# 0  0.828210  0.627810        0.142857
# 1  0.767205  0.455096        0.571429
# 2  0.880595  0.485477        0.571429
# 3  0.912755  0.685498        0.571429
# 4  0.893026  0.423094        0.571429
#
#                                      similar_artists
# 0  ['AR9Z7JB1187B99DB3D', 'ARC1SF21187FB51D0F', '...
# 1  ['ARHAUVU122BCFCBA38', 'AR258TI11C8A416B5B', '...
# 2  ['ARNHMFD1187FB3B3F6', 'ARELPXQ1187FB384FD', '...
# 3  ['AR23C041187FB4D534', 'ARZER7I1187FB385AF', '...
# 4  ['AR3NPVS1187FB5108F', 'ARMKBL21187FB38230', '...

# %% [markdown]
# ## podela train test val

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

izvor_interakcija = df_finalni

train_list = []
val_list = []
test_list = []

for user_id, group in izvor_interakcija.groupby("user_id"):
    n_samples = len(group)
    group_shuffled = group.sample(frac=1, random_state=42) # Uvek prvo mešamo

    # 1. korisnici sa 6 ili više pesama (70% train, 15% val, 15% test)
    if n_samples >= 6:
        train_temp, test_val = train_test_split(group, test_size=0.30, random_state=42)
        val, test = train_test_split(test_val, test_size=0.50, random_state=42) # Delimo onih 30% na pola
        
        train_list.append(train_temp)
        val_list.append(val)
        test_list.append(test)

    # 2. korisnici sa 3, 4 ili 5 pesama (1 train, 1 val, 1 test, ostatak u train)
    elif 3 <= n_samples <= 5:
        u_train = group_shuffled.iloc[3:]
        u_val = group_shuffled.iloc[[1]]
        u_test = group_shuffled.iloc[[2]]
        
        train_list.append(u_train)
        val_list.append(u_val)
        test_list.append(u_test)

    # 3. korisnici sa tačno 2 pesme (1 train, 1 test, val ostaje prazan)
    elif n_samples == 2:
        u_train = group_shuffled.iloc[[0]]
        u_test = group_shuffled.iloc[[1]]
        
        train_list.append(u_train)
        test_list.append(u_test)

    # 4. korisnici sa samo 1 pesmom (sve ide u train)
    else:
        train_list.append(group)

df_train = pd.concat(train_list, ignore_index=True)
df_val = pd.concat(val_list, ignore_index=True)
df_test = pd.concat(test_list, ignore_index=True)

print(f"Train: {df_train.shape[0]}, Val: {df_val.shape[0]}, Test: {df_test.shape[0]}")
# Out:
# Train: 168633, Val: 40419, Test: 54319

# %%
df_train.sample(5)
# Out:
#                                         user_id             song_id  \
# 14022  82c9e891daf1ca9ec12c99212d5c39b80546369c  SONQBUB12A6D4F8ED0
# 53949                                        JM  SOPIFJT12A81C221AC
# 35896                                    Collab  SOAOPCG12AC468D27E
# 92863                                 Slow jams  SOUVKXW12A8C1427AC
# 83664                                  Roadtrip  SOOXLKF12A6D4F594A
#
#        play_count           artist_id  \
# 14022           6  ARFCUN31187B9AD578
# 53949           1  ARAZCWP129462A97F1
# 35896           1  ARH6W4X1187B99274F
# 92863           1  ARPDVPJ1187B9ADBE9
# 83664           1  ARF5M7Q1187FB501E8
#
#                                             artist_terms  loudness     tempo  \
# 14022  ['blues', 'hard rock', 'rock', 'england', 'lon...  0.790764  0.530130
# 53949  ['reggae', 'roots reggae', 'rock steady', 'dan...  0.817560  0.565708
# 35896  ['british pop', 'experimental rock', 'rock', '...  0.766266  0.467344
# 92863  ['hip hop', 'r&b', 'ballad', 'gangster rap', '...  0.911778  0.563026
# 83664  ['pop', 'rock', 'alternative', 'modern rock', ...  0.898044  0.570400
#
#        time_signature                                    similar_artists
# 14022        0.142857  ['ARSAIUN1187FB398D3', 'ARC73361187B9B42BD', '...
# 53949        0.571429  ['ARVIZLO1187FB3DA48', 'ARGPGVF11C8A4151E4', '...
# 35896        0.571429  ['ARN5NHX1187FB4F755', 'ARFC93D1187FB49D2E', '...
# 92863        0.571429  ['ARAWOLW1187FB3AB70', 'ARLMXEA1187B9A7D04', '...
# 83664        0.571429  ['ARY53RR1187B9AE485', 'ARVLXWP1187FB5B94A', '...

# %%
df_test.sample(5)
# Out:
#                                         user_id             song_id  \
# 374                             $$hoe anthems$$  SORZCIC12A6310ECC9
# 9573                                  Childhood  SOFQBMN12A8C1428AD
# 3000   5fc7d10b20b563cc6975ebcc7fa832a33288dbbc  SOHMBBX12A58A7926C
# 45367                                       new  SOSTXYN12A6D4F67D4
# 30473                              Spring Break  SOPVXLX12A8C1402D5
#
#        play_count           artist_id  \
# 374             1  ARVBRGZ1187FB4675A
# 9573            1  AR65K7A1187FB4DAA4
# 3000            3  AR74Q3R1187B9B24C3
# 45367           1  AR82DJK1187B991107
# 30473           1  AR3JMC51187B9AE49D
#
#                                             artist_terms  loudness     tempo  \
# 374          ['rock', 'pop', 'ballad', 'club', 'grunge']  0.918616  0.517616
# 9573   ['hip hop', 'pop', 'rock', 'soul', 'adult cont...  0.862878  0.319981
# 3000   ['sympho black metal', 'progressive metal', 'h...  0.875749  0.296795
# 45367  ['rap', 'hip hop', 'new wave', 'electro', 'und...  0.871842  0.264709
# 30473  ['teen pop', 'pop', 'rock', 'adult contemporar...  0.891092  0.429129
#
#        time_signature                                    similar_artists
# 374          0.571429  ['ARTDQRC1187FB4EFD4', 'ARAOYXM1187FB524F6', '...
# 9573         0.142857  ['ART4QZC1187FB51612', 'ARKSZW81187B9B695D', '...
# 3000         0.714286  ['ARRHD2X1187B9B389E', 'ARB1EH51187B9AD122', '...
# 45367        0.428571  ['ARV4KO21187FB38008', 'AR4WHYC1187B9896E7', '...
# 30473        0.571429  ['AR03BDP1187FB5B324', 'AR5YRCN1187B98E3C8', '...

# %%
df_val.sample(5)
# Out:
#                   user_id             song_id  play_count           artist_id  \
# 26430       Wedding Party  SOCWJDB12A58A776AF           1  ARWPYQI1187FB4D55A
# 33039           mountains  SOPOPLW12A8C13A905           1  ARJV0U41187B9AB715
# 233    #throwbackthursday  SOSGQPS12A8AE48538           1  ARXOTQH1187FB57084
# 24496           Throwback  SOKMBQK12A8C1450CE           1  ARPDVPJ1187B9ADBE9
# 24547           Throwback  SOFIFUK12A8C1393F8           1  AR03BDP1187FB5B324
#
#                                             artist_terms  loudness     tempo  \
# 26430  ['dance pop', 'rock', 'pop', 'england', 'adult...  0.840717  0.431305
# 33039  ['pop punk', 'punk', 'pop', 'punk pop', 'emo p...  0.818671  0.334641
# 233          ['r&b', 'hip hop', 'rap', 'urban', 'blues']  0.905342  0.532660
# 24496  ['hip hop', 'r&b', 'ballad', 'gangster rap', '...  0.880136  0.483035
# 24547  ['dance pop', 'teen pop', 'pop rock', 'electro...  0.917562  0.324665
#
#        time_signature                                    similar_artists
# 26430        0.571429  ['ARCJMMQ1187B98D1FD', 'ARY7CAU1187B98A4F6', '...
# 33039        0.571429  ['ARG72Q21187FB36243', 'ARW5QWS1187FB57C1B', '...
# 233          0.571429  ['ARAWOLW1187FB3AB70', 'ARF33H31187FB45223', '...
# 24496        0.714286  ['ARAWOLW1187FB3AB70', 'ARLMXEA1187B9A7D04', '...
# 24547        0.428571  ['ARX6TAQ11C8A415850', 'ARY7CAU1187B98A4F6', '...

# %%
df_train.to_csv('df_train.csv', index=False)

# %%
df_test.to_csv('df_test.csv', index=False)

# %%
df_val.to_csv('df_val.csv', index=False)

# %% [markdown]
# ## prosirivanje train df

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import MinMaxScaler, MultiLabelBinarizer

df_sinteticki = df_train.copy()


df_pesme = df_sinteticki.drop_duplicates(subset=["song_id"]).copy()

df_pesme["artist_terms"] = df_pesme["artist_terms"].fillna("")

def osiguraj_listu(x):
    if isinstance(x, list):
        return x
    if isinstance(x, str):
        x_clean = x.replace("[", "").replace("]", "").replace("'", "")
        if x_clean.strip() == "":
            return []
        return [tag.strip() for tag in x_clean.split(",") if tag.strip()]
    return []

df_pesme["artist_terms"] = df_pesme["artist_terms"].apply(osiguraj_listu)


num_kolone = ["loudness", "tempo", "time_signature"] ## dodaj mode pretposlednje
for kolona in num_kolone:
    medijana = df_pesme[kolona].median()
    df_pesme[kolona] = df_pesme[kolona].fillna(medijana)


mlb = MultiLabelBinarizer()
izrazi_kodirani = mlb.fit_transform(df_pesme["artist_terms"])
df_izrazi = pd.DataFrame(
    izrazi_kodirani, columns=mlb.classes_, index=df_pesme.index
)

scaler = MinMaxScaler()
audio_skalirano = scaler.fit_transform(df_pesme[num_kolone])
df_audio = pd.DataFrame(
    audio_skalirano, columns=num_kolone, index=df_pesme.index
)

X_features = pd.concat([df_audio, df_izrazi], axis=1)

pesma_indeks_mapa = df_pesme["song_id"].tolist()


k_susedi = 10
knn = NearestNeighbors(n_neighbors=k_susedi, metric="cosine")
knn.fit(X_features)

udaljenosti, indeksi = knn.kneighbors(X_features)

komsije_mape = {}
for i, song_id in enumerate(pesma_indeks_mapa):
    top_komsije_indeksi = indeksi[i][1:]
    top_komsije_id = [pesma_indeks_mapa[idx] for idx in top_komsije_indeksi]
    komsije_mape[song_id] = top_komsije_id

korisnik_slusao = (
    df_sinteticki.groupby("user_id")["song_id"].apply(set).to_dict()
)

meta_pesama_mapa = df_pesme.set_index("song_id").to_dict(orient="index")

jake_interakcije = df_sinteticki[df_sinteticki["play_count"] >= 2]

novi_redovi = []

for idx, row in jake_interakcije.iterrows():
    user = row["user_id"]
    trenutna_pesma = row["song_id"]

    potencijalne_komsije = komsije_mape.get(trenutna_pesma, [])
    vec_slusane = korisnik_slusao.get(user, set())

    for komsija_id in potencijalne_komsije:
        if komsija_id not in vec_slusane:
            meta = meta_pesama_mapa[komsija_id]

            sinteticki_red = {
                "user_id": user,
                "song_id": komsija_id,
                "play_count": 1,  
                "artist_id": meta["artist_id"],
                "artist_terms": meta["artist_terms"],
                "loudness": meta["loudness"],
                "tempo": meta["tempo"],
                #"mode": meta["mode"],
                "time_signature": meta["time_signature"],
                "similar_artists": meta["similar_artists"],
            }
            novi_redovi.append(sinteticki_red)

if novi_redovi:
    df_novi_podaci = pd.DataFrame(novi_redovi).drop_duplicates(
        subset=["user_id", "song_id"]
    )
    df_trainveci = pd.concat([df_sinteticki, df_novi_podaci], ignore_index=True)
    print(f"Uspešno dodato {len(df_novi_podaci)} novih objektivnih interakcija!")
else:
    df_trainveci = df_sinteticki.copy()
    print("Nije pronađena nijedna nova interakcija za dodavanje.")

n_users_novi = df_trainveci["user_id"].nunique()
n_items_novi = df_trainveci["song_id"].nunique()
nova_gustina = (len(df_trainveci) / (n_users_novi * n_items_novi)) * 100

print(f"Stari broj redova: {len(df_sinteticki)}")
print(f"Novi broj redova: {len(df_trainveci)}")
print(f"Nova gustina matrice je: {nova_gustina:.4f}%")
# Out:
# Uspešno dodato 31706 novih objektivnih interakcija!
# Stari broj redova: 168633
# Novi broj redova: 200339
# Nova gustina matrice je: 0.3283%

# %%
print("broj pesama je", df_trainveci['song_id'].nunique())
print("broj usera je", df_trainveci['user_id'].nunique())
print("ukupno play countova", sum(df_trainveci['play_count']))
print("play count prosek po korisniku", sum(df_trainveci['play_count'])/df_trainveci['user_id'].nunique())
broj_interakcija = len(df_trainveci)
print("broj interakcija", broj_interakcija)
moguce_interakcije = df_trainveci['user_id'].nunique() * df_trainveci['song_id'].nunique()
gustina = (broj_interakcija / moguce_interakcije) * 100
print(f"Gustina matrice: {gustina:.4f}%")
# Out:
# broj pesama je 2262
# broj usera je 26974
# ukupno play countova 216384
# play count prosek po korisniku 8.021947060131978
# broj interakcija 200339
# Gustina matrice: 0.3283%

# %%
print(max(df_train.play_count))
print(min(df_train.play_count))
print(sum(df_train.play_count))
print(len(df_train))
print(sum(df_train.play_count)/len(df_train))
print(df_train.play_count.median())
# Out:
# 189
# 1
# 184678
# 168633
# 1.095147450380412
# 1.0

# %%
print(max(df_trainveci.play_count))
print(min(df_trainveci.play_count))
print(sum(df_trainveci.play_count))
print(len(df_trainveci))
print(sum(df_trainveci.play_count)/len(df_trainveci))
print(df_trainveci.play_count.median())
# Out:
# 189
# 1
# 216384
# 200339
# 1.0800892487234137
# 1.0

# %%
df_train.head()
# Out:
#       user_id             song_id  play_count           artist_id  \
# 0         bn   SOSKFIT12A8C14224A           1  ARM7EDF1187B9B3FA1
# 1   2000s pop  SOPVXLX12A8C1402D5           1  AR3JMC51187B9AE49D
# 2        60's  SONFECQ12AB017EFF7           1  AROCBZZ11E2835D652
# 3        60's  SONFECQ12AB017EFF7           1  AROCBZZ11E2835D652
# 4        60's  SONFECQ12AB017EFF7           1  AROCBZZ11E2835D652
#
#                                         artist_terms  loudness     tempo  \
# 0  ['heavy metal', 'hard rock', 'rock', 'metal', ...  0.914632  0.510554
# 1  ['teen pop', 'pop', 'rock', 'adult contemporar...  0.891092  0.429129
# 2  ["rock 'n roll", 'blues-rock', 'british invasi...  0.823613  0.469436
# 3  ["rock 'n roll", 'blues-rock', 'british invasi...  0.823613  0.469436
# 4  ["rock 'n roll", 'blues-rock', 'british invasi...  0.823613  0.469436
#
#    time_signature                                    similar_artists
# 0        1.000000  ['ARE8GLF1187FB52532', 'ARKUDKL1296AAF0B2F', '...
# 1        0.571429  ['AR03BDP1187FB5B324', 'AR5YRCN1187B98E3C8', '...
# 2        0.571429  ['ARQNR1G1187B9AE88F', 'ARPISA41187FB3DE42', '...
# 3        0.571429  ['ARQNR1G1187B9AE88F', 'ARPISA41187FB3DE42', '...
# 4        0.571429  ['ARQNR1G1187B9AE88F', 'ARPISA41187FB3DE42', '...

# %%
df_trainveci.head()
# Out:
#       user_id             song_id  play_count           artist_id  \
# 0         bn   SOSKFIT12A8C14224A           1  ARM7EDF1187B9B3FA1
# 1   2000s pop  SOPVXLX12A8C1402D5           1  AR3JMC51187B9AE49D
# 2        60's  SONFECQ12AB017EFF7           1  AROCBZZ11E2835D652
# 3        60's  SONFECQ12AB017EFF7           1  AROCBZZ11E2835D652
# 4        60's  SONFECQ12AB017EFF7           1  AROCBZZ11E2835D652
#
#                                         artist_terms  loudness     tempo  \
# 0  ['heavy metal', 'hard rock', 'rock', 'metal', ...  0.914632  0.510554
# 1  ['teen pop', 'pop', 'rock', 'adult contemporar...  0.891092  0.429129
# 2  ["rock 'n roll", 'blues-rock', 'british invasi...  0.823613  0.469436
# 3  ["rock 'n roll", 'blues-rock', 'british invasi...  0.823613  0.469436
# 4  ["rock 'n roll", 'blues-rock', 'british invasi...  0.823613  0.469436
#
#    time_signature                                    similar_artists
# 0        1.000000  ['ARE8GLF1187FB52532', 'ARKUDKL1296AAF0B2F', '...
# 1        0.571429  ['AR03BDP1187FB5B324', 'AR5YRCN1187B98E3C8', '...
# 2        0.571429  ['ARQNR1G1187B9AE88F', 'ARPISA41187FB3DE42', '...
# 3        0.571429  ['ARQNR1G1187B9AE88F', 'ARPISA41187FB3DE42', '...
# 4        0.571429  ['ARQNR1G1187B9AE88F', 'ARPISA41187FB3DE42', '...

# %%
# stari
br_tr = sum(df_train.play_count)
br_te = sum(df_test.play_count)
br_va = sum(df_val.play_count)
ukupno = br_tr + br_te + br_va

print("--- stari skup ---")
print("train:", br_tr)
print("test:", br_te)
print("odnos, train:", (br_tr / ukupno) * 100, "%, test:", (br_te / ukupno) * 100, "%, val:", (br_va / ukupno) * 100, "%")

# veci
br_tr = sum(df_trainveci.play_count)
br_te = sum(df_test.play_count)
br_va = sum(df_val.play_count)
ukupno = br_tr + br_te + br_va

print('\n')
print("--- stari skup ---")
print("train:", br_tr)
print("test:", br_te)
print("odnos, train:", (br_tr / ukupno) * 100, "%, test:", (br_te / ukupno) * 100, "%, val:", (br_va / ukupno) * 100, "%")
# Out:
# --- stari skup ---
# train: 184678
# test: 59975
# odnos, train: 64.18894025233742 %, test: 20.845643182371138 %, val: 14.96541656529144 %
#
#
# --- stari skup ---
# train: 216384
# test: 59975
# odnos, train: 67.74363212863476 %, test: 18.776454529516368 %, val: 13.479913341848873 %

# %%
df_trainveci.to_csv('df_trainveci.csv', index=False)
